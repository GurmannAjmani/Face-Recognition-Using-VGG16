# %% [markdown]
# ## IMPORTING ALL LIBRARIES

# %%
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Input
import matplotlib.pyplot as plt
from tensorflow.keras.layers import BatchNormalization
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19,VGG16
from tensorflow.keras.models import Model
# Out:
# 2024-06-06 04:11:29.083735: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 04:11:29.083788: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 04:11:29.085381: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## CREATING THE TRAINING AND VALIDATION DATASET USING IMAGEDATAGENERATOR

# %%
generator = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    validation_split=0.1
)

# %%
train_data = generator.flow_from_directory(
    "/kaggle/input/face-recognition-dataset/Original Images/Original Images",
    target_size=(224, 224),
    batch_size=32,
    subset="training" ,
)
# Out:
# Found 2318 images belonging to 31 classes.

# %%
val_data= generator.flow_from_directory(
    "/kaggle/input/face-recognition-dataset/Original Images/Original Images",
    target_size=(224,224),
    batch_size=32,
    subset="validation"
)
# Out:
# Found 244 images belonging to 31 classes.

# %%
targets = list(train_data.class_indices.keys())

# %% [markdown]
# ## LOADING VGG16 MODEL

# %%
vgg = VGG16(input_shape=[224,224,3], weights='imagenet', include_top=False)

# %% [markdown]
# ## MODEL CREATION

# %%
for layer in vgg.layers:
    layer.trainable = False

x = Flatten()(vgg.output)
x= Dropout(0.4)(x)
x = Dense(31, activation='softmax')(x)

model = Model(inputs=vgg.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 31)             │       777,759 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,492,447 (59.10 MB)
#  Trainable params: 777,759 (2.97 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## MODEL TRAINING

# %%
history = model.fit(train_data, epochs=25, validation_data=val_data, batch_size=16)
# Out:
# Epoch 1/25
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  1/73 ━━━━━━━━━━━━━━━━━━━━ 45:31 38s/step - accuracy: 0.0938 - loss: 4.1129
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717647133.365889     597 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1717647133.384978     597 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 952ms/step - accuracy: 0.0972 - loss: 4.1673
# W0000 00:00:1717647205.784067     596 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.0976 - loss: 4.1620 - val_accuracy: 0.2459 - val_loss: 2.7329
# Epoch 2/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 71s 874ms/step - accuracy: 0.3188 - loss: 2.4470 - val_accuracy: 0.3156 - val_loss: 2.3998
# Epoch 3/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 65s 806ms/step - accuracy: 0.4426 - loss: 1.9822 - val_accuracy: 0.3320 - val_loss: 2.5439
# Epoch 4/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 65s 813ms/step - accuracy: 0.4714 - loss: 1.8242 - val_accuracy: 0.3811 - val_loss: 2.3145
# Epoch 5/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 65s 810ms/step - accuracy: 0.5666 - loss: 1.5299 - val_accuracy: 0.3811 - val_loss: 2.4990
# Epoch 6/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 62s 774ms/step - accuracy: 0.6037 - loss: 1.4463 - val_accuracy: 0.3852 - val_loss: 2.4357
# Epoch 7/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 65s 813ms/step - accuracy: 0.5934 - loss: 1.4048 - val_accuracy: 0.3770 - val_loss: 2.5455
# Epoch 8/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 65s 818ms/step - accuracy: 0.6409 - loss: 1.2650 - val_accuracy: 0.4303 - val_loss: 2.1992
# Epoch 9/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 840ms/step - accuracy: 0.6744 - loss: 1.1451 - val_accuracy: 0.3525 - val_loss: 2.3200
# Epoch 10/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 835ms/step - accuracy: 0.6660 - loss: 1.1528 - val_accuracy: 0.4631 - val_loss: 2.1734
# Epoch 11/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 830ms/step - accuracy: 0.6891 - loss: 1.0130 - val_accuracy: 0.4262 - val_loss: 2.2256
# Epoch 12/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 66s 837ms/step - accuracy: 0.6863 - loss: 1.0042 - val_accuracy: 0.4549 - val_loss: 2.3010
# Epoch 13/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 831ms/step - accuracy: 0.6995 - loss: 0.9830 - val_accuracy: 0.4344 - val_loss: 2.1951
# Epoch 14/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 66s 829ms/step - accuracy: 0.7273 - loss: 0.9084 - val_accuracy: 0.4385 - val_loss: 2.2605
# Epoch 15/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 839ms/step - accuracy: 0.7615 - loss: 0.8104 - val_accuracy: 0.3852 - val_loss: 2.4707
# Epoch 16/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 66s 824ms/step - accuracy: 0.7165 - loss: 0.9248 - val_accuracy: 0.4221 - val_loss: 2.3308
# Epoch 17/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 66s 823ms/step - accuracy: 0.7614 - loss: 0.8648 - val_accuracy: 0.4590 - val_loss: 2.2876
# Epoch 18/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 66s 840ms/step - accuracy: 0.7523 - loss: 0.7837 - val_accuracy: 0.3811 - val_loss: 2.4950
# Epoch 19/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 837ms/step - accuracy: 0.7589 - loss: 0.7904 - val_accuracy: 0.3975 - val_loss: 2.3903
# Epoch 20/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 844ms/step - accuracy: 0.7595 - loss: 0.7893 - val_accuracy: 0.4754 - val_loss: 2.4802
# Epoch 21/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 840ms/step - accuracy: 0.7534 - loss: 0.8363 - val_accuracy: 0.4385 - val_loss: 2.3450
# Epoch 22/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 843ms/step - accuracy: 0.7486 - loss: 0.8449 - val_accuracy: 0.4098 - val_loss: 2.4469
# Epoch 23/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 827ms/step - accuracy: 0.7800 - loss: 0.7383 - val_accuracy: 0.4385 - val_loss: 2.5269
# Epoch 24/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 66s 823ms/step - accuracy: 0.7895 - loss: 0.7192 - val_accuracy: 0.4057 - val_loss: 2.7504
# Epoch 25/25
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 67s 827ms/step - accuracy: 0.7821 - loss: 0.7050 - val_accuracy: 0.4303 - val_loss: 2.6076

# %% [markdown]
# **EVALUATING MODEL ON TRAINING AND VALIDATION DATASET**

# %%
print(f"Training loss, training accuracy: ",model.evaluate(train_data))
print(f"validation loss, validation accuracy: ",model.evaluate(val_data))
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 59s 808ms/step - accuracy: 0.8353 - loss: 0.5433
# Training loss, training accuracy:  [0.542137086391449, 0.8377912044525146]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - accuracy: 0.4214 - loss: 2.6828
# validation loss, validation accuracy:  [2.6784985065460205, 0.43852460384368896]

# %% [markdown]
# ## VISUALISING THE RESULT

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'],label="accuracy")
plt.plot(history.history['val_accuracy'],label="val_accuracy")
plt.legend()

# %%
plt.plot(history.history['loss'],label="loss")
plt.plot(history.history['val_loss'],label="val_loss")
plt.legend()
